# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lgC=np.array([4.77,4.48,4.18,3.77,3.48,3.18,2.77,2.48])
T=np.array([62.5,82,96.7,94.9,102.1,101.2,106.1,102.6])
a=np.array([148.4,77.5,43.7,29.8,20.3,11.8,7.4,10.3])
c=np.array(10**(-lgC))
e=np.array(a/c)

# %%
e
# Out:
# array([8.73843985e+06, 2.34046258e+06, 6.61426266e+05, 1.75475409e+05,
#        6.13050199e+04, 1.78600227e+04, 4.35744305e+03, 3.11055027e+03])

# %%
plt.plot(lgC,T)
plt.grid(True)
plt.xlabel("-lgC")
plt.ylabel("T,%")
# Out:
# Text(0, 0.5, 'T,%')

# %%
plt.plot(lgC,a)
plt.grid(True)
plt.xlabel("-lgC")
plt.ylabel("œ,См/м")
# Out:
# Text(0, 0.5, 'œ,См/м')

# %%
plt.plot(lgC,e)
plt.grid(True)
plt.xlabel("-lgC")
plt.ylabel("λ,См·м2")
# Out:
# Text(0, 0.5, 'λ,См·м2')
